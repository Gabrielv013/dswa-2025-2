# %% [markdown]
# ### DSWA + Visagio - Previsão de Demanda Diária
#
# ### Gabriel Varano, RA 822484
# ---

# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor

df_produto = pd.read_csv('produto.csv')
df_test = pd.read_csv('test.csv')
df_train = pd.read_csv('train.csv')

# %%
display(df_produto)
# Out:
#            SKU                                       NOME_PRODUTO  \
# 0          3.0  COCO RALADO GROSSO KG                         ...
# 1          4.0  ICE TEA LEAO LATA 340ML                       ...
# 2          5.0  TAHINE ISTAMBUL 200G                          ...
# 3          6.0  AMENDOIM MOIDO KG                             ...
# 4          7.0  HALAWI ISTAMBUL LATA 500G                     ...
# ...        ...                                                ...
# 6495  171874.0  BARRA BOLD BAR BANOFFEE 60G NV                ...
# 6496  171877.0  VINHO CASIL.D.CARNAVAL SPECTACULAR CARBENET 75...
# 6497  171878.0  VINHO CASIL.D.CARNAVAL FANTASTIC SWEET 750ML C...
# 6498  171887.0  BATATA PALHA EXTRA FINA VISCONTI 100G         ...
# 6499       NaN                                                NaN
#
#                     CATEGORIA        SUBCATEGORIA
# 0                     Doceria         Confeitaria
# 1                         NaN                 NaN
# 2                  Pelo Mundo       Pastas Árabes
# 3     Castanhas & Oleaginosas  Oleaginosas moídas
# 4                  Pelo Mundo       Pastas Árabes
# ...                       ...                 ...
# 6495              Suplementos           Barrinhas
# 6496      Vinhos & Espumantes              Tintos
# 6497      Vinhos & Espumantes              Tintos
# 6498                Biscoitos      Batatas palhas
# 6499                      NaN                 NaN
#
# [6500 rows x 4 columns]

# %%
display(df_test)
# Out:
#         id        data    sku  cod_filial    filial unidade
# 0        0  2024-12-02      9      101032       RUA      KG
# 1        1  2024-12-03      9      101032       RUA      KG
# 2        2  2024-12-04      9      101032       RUA      KG
# 3        3  2024-12-05      9      101032       RUA      KG
# 4        4  2024-12-06      9      101032       RUA      KG
# ...    ...         ...    ...         ...       ...     ...
# 2748  2748  2024-12-27  24706      101042  SHOPPING      KG
# 2749  2749  2024-12-28  24706      101042  SHOPPING      KG
# 2750  2750  2024-12-29  24706      101042  SHOPPING      KG
# 2751  2751  2024-12-30  24706      101042  SHOPPING      KG
# 2752  2752  2024-12-31  24706      101042  SHOPPING      KG
#
# [2753 rows x 6 columns]

# %%
display(df_train)
# Out:
#              data    sku  cod_filial    filial unidade  demanda  faturamento  \
# 0      2024-01-02      9      101032       RUA      KG    0.430        30.12
# 1      2024-01-03      9      101032       RUA      KG    0.238        16.65
# 2      2024-01-04      9      101032       RUA      KG    0.400        27.97
# 3      2024-01-05      9      101032       RUA      KG    0.378        26.45
# 4      2024-01-06      9      101032       RUA      KG    0.766        53.58
# ...           ...    ...         ...       ...     ...      ...          ...
# 27574  2024-11-26  24706      101042  SHOPPING      KG    1.330       132.87
# 27575  2024-11-27  24706      101042  SHOPPING      KG    0.426        42.55
# 27576  2024-11-28  24706      101042  SHOPPING      KG    1.272       127.07
# 27577  2024-11-29  24706      101042  SHOPPING      KG    0.508        50.75
# 27578  2024-11-30  24706      101042  SHOPPING      KG    2.156       215.39
#
#        num_transacoes  clientes_unicos
# 0                   3                3
# 1                   2                2
# 2                   2                2
# 3                   2                2
# 4                   4                4
# ...               ...              ...
# 27574               7                7
# 27575               2                2
# 27576               7                7
# 27577               3                3
# 27578              12               12
#
# [27579 rows x 9 columns]

# %%
display(df_produto.isna().sum())
# Out:
# SKU                1
# NOME_PRODUTO       1
# CATEGORIA       2002
# SUBCATEGORIA    2002
# dtype: int64

# %%
df_produto = df_produto[:-1]
display(df_produto)
# Out:
#            SKU                                       NOME_PRODUTO  \
# 0          3.0  COCO RALADO GROSSO KG                         ...
# 1          4.0  ICE TEA LEAO LATA 340ML                       ...
# 2          5.0  TAHINE ISTAMBUL 200G                          ...
# 3          6.0  AMENDOIM MOIDO KG                             ...
# 4          7.0  HALAWI ISTAMBUL LATA 500G                     ...
# ...        ...                                                ...
# 6494  171803.0  CREME DE LEITE DOCE ECILA 35% GARRAFA 450G 302...
# 6495  171874.0  BARRA BOLD BAR BANOFFEE 60G NV                ...
# 6496  171877.0  VINHO CASIL.D.CARNAVAL SPECTACULAR CARBENET 75...
# 6497  171878.0  VINHO CASIL.D.CARNAVAL FANTASTIC SWEET 750ML C...
# 6498  171887.0  BATATA PALHA EXTRA FINA VISCONTI 100G         ...
#
#                     CATEGORIA        SUBCATEGORIA
# 0                     Doceria         Confeitaria
# 1                         NaN                 NaN
# 2                  Pelo Mundo       Pastas Árabes
# 3     Castanhas & Oleaginosas  Oleaginosas moídas
# 4                  Pelo Mundo       Pastas Árabes
# ...                       ...                 ...
# 6494             Refrigerados              Leites
# 6495              Suplementos           Barrinhas
# 6496      Vinhos & Espumantes              Tintos
# 6497      Vinhos & Espumantes              Tintos
# 6498                Biscoitos      Batatas palhas
#
# [6499 rows x 4 columns]

# %%
display(df_produto.isna().sum())
# Out:
# SKU                0
# NOME_PRODUTO       0
# CATEGORIA       2001
# SUBCATEGORIA    2001
# dtype: int64

# %%
df_produto = df_produto.fillna("Sem Categoria")
df_produto["SKU"] = df_produto["SKU"].astype(int)
display(df_produto.isna().sum())
display(df_produto)
# Out:
# SKU             0
# NOME_PRODUTO    0
# CATEGORIA       0
# SUBCATEGORIA    0
# dtype: int64
#          SKU                                       NOME_PRODUTO  \
# 0          3  COCO RALADO GROSSO KG                         ...
# 1          4  ICE TEA LEAO LATA 340ML                       ...
# 2          5  TAHINE ISTAMBUL 200G                          ...
# 3          6  AMENDOIM MOIDO KG                             ...
# 4          7  HALAWI ISTAMBUL LATA 500G                     ...
# ...      ...                                                ...
# 6494  171803  CREME DE LEITE DOCE ECILA 35% GARRAFA 450G 302...
# 6495  171874  BARRA BOLD BAR BANOFFEE 60G NV                ...
# 6496  171877  VINHO CASIL.D.CARNAVAL SPECTACULAR CARBENET 75...
# 6497  171878  VINHO CASIL.D.CARNAVAL FANTASTIC SWEET 750ML C...
# 6498  171887  BATATA PALHA EXTRA FINA VISCONTI 100G         ...
#
#                     CATEGORIA        SUBCATEGORIA
# 0                     Doceria         Confeitaria
# 1               Sem Categoria       Sem Categoria
# 2                  Pelo Mundo       Pastas Árabes
# 3     Castanhas & Oleaginosas  Oleaginosas moídas
# 4                  Pelo Mundo       Pastas Árabes
# ...                       ...                 ...
# 6494             Refrigerados              Leites
# 6495              Suplementos           Barrinhas
# 6496      Vinhos & Espumantes              Tintos
# 6497      Vinhos & Espumantes              Tintos
# 6498                Biscoitos      Batatas palhas
#
# [6499 rows x 4 columns]

# %%
df_train['data'] = pd.to_datetime(df_train['data'])
df_test['data'] = pd.to_datetime(df_test['data'])

# %%
df_train = df_train.merge(df_produto, left_on='sku', right_on='SKU').drop(columns=['SKU', "NOME_PRODUTO", "faturamento", "num_transacoes", "clientes_unicos"])
df_test = df_test.merge(df_produto, left_on='sku', right_on='SKU').drop(columns=['SKU', 'NOME_PRODUTO'])

# %%
display(df_train)
# Out:
#             data    sku  cod_filial    filial unidade  demanda  \
# 0     2024-01-02      9      101032       RUA      KG    0.430
# 1     2024-01-03      9      101032       RUA      KG    0.238
# 2     2024-01-04      9      101032       RUA      KG    0.400
# 3     2024-01-05      9      101032       RUA      KG    0.378
# 4     2024-01-06      9      101032       RUA      KG    0.766
# ...          ...    ...         ...       ...     ...      ...
# 27574 2024-11-26  24706      101042  SHOPPING      KG    1.330
# 27575 2024-11-27  24706      101042  SHOPPING      KG    0.426
# 27576 2024-11-28  24706      101042  SHOPPING      KG    1.272
# 27577 2024-11-29  24706      101042  SHOPPING      KG    0.508
# 27578 2024-11-30  24706      101042  SHOPPING      KG    2.156
#
#                      CATEGORIA       SUBCATEGORIA
# 0      Castanhas & Oleaginosas  Castanhas de Caju
# 1      Castanhas & Oleaginosas  Castanhas de Caju
# 2      Castanhas & Oleaginosas  Castanhas de Caju
# 3      Castanhas & Oleaginosas  Castanhas de Caju
# 4      Castanhas & Oleaginosas  Castanhas de Caju
# ...                        ...                ...
# 27574                   Frutas              Secas
# 27575                   Frutas              Secas
# 27576                   Frutas              Secas
# 27577                   Frutas              Secas
# 27578                   Frutas              Secas
#
# [27579 rows x 8 columns]

# %%
def caracteristicas_data(df):
    #df['mes'] = df['data'].dt.month
    df['dia_semana'] = df['data'].dt.dayofweek
    #df['dia_mes'] = df['data'].dt.day
    #df['final_semana'] = df['dia_semana'].isin([5, 6]).astype(int)
    #df['inicio_mes'] = df['data'].dt.is_month_start.astype(int)
    return df

df_train = caracteristicas_data(df_train)
df_test = caracteristicas_data(df_test)

df_train = df_train.sort_values(["sku", "data"])
df_test = df_test.sort_values(["sku", "data"])

# %%
df_train["lag_1"] = df_train.groupby("sku")["demanda"].shift(1)
df_train["lag_7"] = df_train.groupby("sku")["demanda"].shift(7)
df_train["lag_14"] = df_train.groupby("sku")["demanda"].shift(14)
df_train["mm_7"] = df_train.groupby("sku")["demanda"].shift(1).rolling(7).mean()
df_train["mm_14"] = df_train.groupby("sku")["demanda"].shift(1).rolling(14).mean()
#df_train["std_7"] = df_train.groupby("sku")["demanda"].shift(1).rolling(7).std()

df_train = df_train.dropna().reset_index(drop=True)

stats_por_sku = df_train.groupby("sku").agg({
"demanda": ["last", "mean", "std"]
})
stats_por_sku.columns = ["last", "mean", "std"]
df_test["lag_1"] = df_test["sku"].map(stats_por_sku["last"])
df_test["lag_7"] = df_test["sku"].map(stats_por_sku["last"])
df_test["lag_14"] = df_test["sku"].map(stats_por_sku["last"])
df_test["mm_7"] = df_test["sku"].map(stats_por_sku["mean"])
df_test["mm_14"] = df_test["sku"].map(stats_por_sku["mean"])
#df_test["std_7"] = df_test["sku"].map(stats_por_sku["std"])

media = df_train["demanda"].mean()
preencher = ["lag_1", "lag_7", "lag_14", "mm_7", "mm_14"]
df_test[preencher] = df_test[preencher].fillna(media)

# %%
display(df_train)
# Out:
#             data    sku  cod_filial    filial unidade  demanda  \
# 0     2024-01-11      9      101032       RUA      KG    0.580
# 1     2024-01-11      9      101042  SHOPPING      KG    1.323
# 2     2024-01-12      9      101032       RUA      KG    0.302
# 3     2024-01-12      9      101042  SHOPPING      KG    1.328
# 4     2024-01-13      9      101032       RUA      KG    0.420
# ...          ...    ...         ...       ...     ...      ...
# 26775 2024-11-28  24706      101042  SHOPPING      KG    1.272
# 26776 2024-11-29  24706      101032       RUA      KG    3.694
# 26777 2024-11-29  24706      101042  SHOPPING      KG    0.508
# 26778 2024-11-30  24706      101032       RUA      KG    2.216
# 26779 2024-11-30  24706      101042  SHOPPING      KG    2.156
#
#                      CATEGORIA       SUBCATEGORIA  dia_semana  lag_1  lag_7  \
# 0      Castanhas & Oleaginosas  Castanhas de Caju           3  0.766  1.592
# 1      Castanhas & Oleaginosas  Castanhas de Caju           3  0.580  0.766
# 2      Castanhas & Oleaginosas  Castanhas de Caju           4  1.323  2.408
# 3      Castanhas & Oleaginosas  Castanhas de Caju           4  0.302  0.348
# 4      Castanhas & Oleaginosas  Castanhas de Caju           5  1.328  1.284
# ...                        ...                ...         ...    ...    ...
# 26775                   Frutas              Secas           3  2.580  2.774
# 26776                   Frutas              Secas           4  1.272  0.792
# 26777                   Frutas              Secas           4  3.694  2.072
# 26778                   Frutas              Secas           5  0.508  1.330
# 26779                   Frutas              Secas           5  2.216  1.858
#
#        lag_14      mm_7     mm_14
# 0       0.430  1.040857  0.823000
# 1       0.258  0.896286  0.833714
# 2       0.238  0.975857  0.909786
# 3       1.306  0.675000  0.914357
# 4       0.400  0.815000  0.915929
# ...       ...       ...       ...
# 26775   0.510  1.690286  1.591571
# 26776   2.254  1.475714  1.646000
# 26777   1.290  1.890286  1.748857
# 26778   3.474  1.666857  1.693000
# 26779   0.672  1.793429  1.603143
#
# [26780 rows x 14 columns]

# %%
display(df_test.sort_values(["data", "sku"]))
# Out:
#         id       data    sku  cod_filial    filial unidade  \
# 28      28 2024-12-01      9      101042  SHOPPING      KG
# 85      85 2024-12-01     51      101042  SHOPPING      KG
# 141    141 2024-12-01     65      101042  SHOPPING      KG
# 195    195 2024-12-01     66      101042  SHOPPING      KG
# 252    252 2024-12-01     86      101042  SHOPPING      KG
# ...    ...        ...    ...         ...       ...     ...
# 2645  2645 2024-12-31  23554      101042  SHOPPING      KG
# 2671  2671 2024-12-31  23980      101032       RUA      KG
# 2697  2697 2024-12-31  23980      101042  SHOPPING      KG
# 2723  2723 2024-12-31  24706      101032       RUA      KG
# 2752  2752 2024-12-31  24706      101042  SHOPPING      KG
#
#                     CATEGORIA       SUBCATEGORIA  dia_semana   lag_1   lag_7  \
# 28    Castanhas & Oleaginosas  Castanhas de Caju           6   4.244   4.244
# 85    Castanhas & Oleaginosas              Nozes           6   0.403   0.403
# 141   Castanhas & Oleaginosas  Castanhas do Pará           6   1.692   1.692
# 195   Castanhas & Oleaginosas  Castanhas do Pará           6   2.932   2.932
# 252                  Matinais            Cereais           6  15.540  15.540
# ...                       ...                ...         ...     ...     ...
# 2645            Mixes da Casa      Mixes da Casa           1   4.726   4.726
# 2671      Bacalhau & Pescados           Bacalhau           1   1.854   1.854
# 2697      Bacalhau & Pescados           Bacalhau           1   1.854   1.854
# 2723                   Frutas              Secas           1   2.156   2.156
# 2752                   Frutas              Secas           1   2.156   2.156
#
#       lag_14       mm_7      mm_14
# 28     4.244   2.069937   2.069937
# 85     0.403   1.527893   1.527893
# 141    1.692   1.392724   1.392724
# 195    2.932   3.232769   3.232769
# 252   15.540  15.213369  15.213369
# ...      ...        ...        ...
# 2645   4.726   2.879081   2.879081
# 2671   1.854  10.541425  10.541425
# 2697   1.854  10.541425  10.541425
# 2723   2.156   1.294048   1.294048
# 2752   2.156   1.294048   1.294048
#
# [2753 rows x 14 columns]

# %%
X_train = df_train.drop(columns=["demanda"])
X_test = df_test.drop(columns=["id"])
y_train = df_train["demanda"]

# %%
display(X_train.dtypes)
# Out:
# data            datetime64[ns]
# sku                      int64
# cod_filial               int64
# filial                  object
# unidade                 object
# CATEGORIA               object
# SUBCATEGORIA            object
# dia_semana               int32
# lag_1                  float64
# lag_7                  float64
# lag_14                 float64
# mm_7                   float64
# mm_14                  float64
# dtype: object

# %%
cat_features = ["sku", "cod_filial", "filial", "unidade", "CATEGORIA", "SUBCATEGORIA"]
for col in cat_features:
    X_train[col] = X_train[col].astype(str)
    X_test[col] = X_test[col].astype(str)

# %%
model = CatBoostRegressor(
    loss_function="RMSE",
    random_seed=111,
    verbose=False,
    cat_features=cat_features
)

param_grid = {
    'iterations': [1000, 2000],
    'learning_rate': [0.01, 0.03, 0.05, 0.1],
    'depth': [4, 5, 6],
    'l2_leaf_reg': [5, 10, 20],
    'random_strength': [1, 2, 5],
    'bagging_temperature': [0, 0.5, 1]
}

result = model.randomized_search(
    param_grid,
    X=X_train,
    y=y_train,
    n_iter=15, 
    partition_random_seed=111,
    shuffle=True,
    stratified=False,
    verbose=False,
    plot=False
)

model.fit(
    X_train,
    y_train,
    early_stopping_rounds=200,
    verbose=200
)
# Out:
# bestTest = 3.669025606
# bestIteration = 1169
#
#
# bestTest = 3.673243058
# bestIteration = 1942
#
#
# bestTest = 3.705188013
# bestIteration = 1998
#
#
# bestTest = 3.660925892
# bestIteration = 683
#
#
# bestTest = 3.679794172
# bestIteration = 821
#
#
# bestTest = 3.640139058
# bestIteration = 1180
#
#
# bestTest = 3.655267681
# bestIteration = 1604
#
#
# bestTest = 3.668637179
# bestIteration = 886
#
#
# bestTest = 3.656950547
# bestIteration = 1095
#
#
# bestTest = 3.659214213
# bestIteration = 1223
#
#
# bestTest = 3.660925892
# bestIteration = 683
#
#
# bestTest = 3.685565424
# bestIteration = 1999
#
#
# bestTest = 3.647888058
# bestIteration = 940
#
#
# bestTest = 3.722970899
# bestIteration = 252
#
#
# bestTest = 3.656310595
# bestIteration = 1340
#
# Training on fold [0/3]
#
# bestTest = 3.836115992
# bestIteration = 1883
#
# Training on fold [1/3]
#
# bestTest = 3.245841757
# bestIteration = 1843
#
# Training on fold [2/3]
#
# bestTest = 3.499167508
# bestIteration = 551
#
# 0:	learn: 7.6891052	total: 57.9ms	remaining: 1m 55s
# 200:	learn: 3.3261244	total: 12.5s	remaining: 1m 51s
# 400:	learn: 3.0789879	total: 24.5s	remaining: 1m 37s
# 600:	learn: 2.8948922	total: 36.1s	remaining: 1m 23s
# 800:	learn: 2.7570648	total: 47.7s	remaining: 1m 11s
# 1000:	learn: 2.6350155	total: 1m	remaining: 1m
# 1200:	learn: 2.5279763	total: 1m 12s	remaining: 48.3s
# 1400:	learn: 2.4343004	total: 1m 24s	remaining: 36s
# 1600:	learn: 2.3585215	total: 1m 34s	remaining: 23.6s
# 1800:	learn: 2.2901537	total: 1m 45s	remaining: 11.6s
# 1999:	learn: 2.2276354	total: 1m 54s	remaining: 0us

# %%
preds = model.predict(X_test)
y_final = preds

submission = pd.DataFrame({
    "id": df_test["id"],
    "demanda": y_final
})
submission["demanda"] = submission["demanda"].clip(lower=0)

submission.to_csv("submission.csv", index=False)

# %%
display(submission.iloc[1106])
# Out:
# id         1105.000000
# demanda       3.554276
# Name: 1105, dtype: float64

# %%
importances = model.get_feature_importance()
feature_names = X_train.columns

fi = pd.DataFrame({
    "feature": feature_names,
    "importance": importances
}).sort_values(by="importance", ascending=False)

display(fi)
# Out:
#          feature  importance
# 11          mm_7   23.860062
# 12         mm_14   20.006152
# 4        unidade   10.539621
# 3         filial    6.639138
# 0           data    6.451047
# 2     cod_filial    6.076245
# 5      CATEGORIA    5.625085
# 7     dia_semana    4.402810
# 10        lag_14    4.285121
# 8          lag_1    4.074309
# 9          lag_7    3.905101
# 1            sku    3.031262
# 6   SUBCATEGORIA    1.104047
